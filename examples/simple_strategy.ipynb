# %%
# %cd /content/drive/My Drive/Colab Notebooks/playing with btc
# Out:
# /content/drive/My Drive/Colab Notebooks/playing with btc

# %%
# !pip install backtrader
# !pip install pyfolio
# For plotting capabilities
# !pip install backtrader[plotting]

# %%
# %matplotlib inline
import pandas as pd
import backtrader as bt
import backtrader.indicators as btind
import backtrader.analyzers as btanalyzers
import datetime

from backtrader.feeds import PandasData

# %%
df = pd.read_csv('bitcoin/btc_4h_2017_2020.csv')
names = ['open', 'high', 'low', 'close', 'volume', 'open_time']
df = df[names]
df
# Out:
#           open      high  ...       volume                open_time
# 0      4261.48   4349.99  ...    82.088865  2017-08-17 04:00:00.000
# 1      4333.32   4485.39  ...    63.619882  2017-08-17 08:00:00.000
# 2      4436.06   4485.39  ...   174.562001  2017-08-17 12:00:00.000
# 3      4352.33   4354.84  ...   225.109716  2017-08-17 16:00:00.000
# 4      4307.56   4369.69  ...   249.769913  2017-08-17 20:00:00.000
# ...        ...       ...  ...          ...                      ...
# 6775  10449.94  10502.79  ...  7823.399186  2020-09-22 04:00:00.000
# 6776  10372.91  10503.00  ...  8386.425935  2020-09-22 08:00:00.000
# 6777  10452.11  10520.00  ...  9044.594223  2020-09-22 12:00:00.000
# 6778  10451.06  10506.22  ...  6701.006892  2020-09-22 16:00:00.000
# 6779  10491.98  10516.67  ...  1303.688983  2020-09-22 20:00:00.000
#
# [6780 rows x 6 columns]

# %% [markdown]
# # ticker and the start and end dates for testing

# %%
format = '%Y-%m-%d %H:%M:%S.%f'
df['open_time'] = pd.to_datetime(df['open_time'], format=format)
df.set_index('open_time', inplace=True)
df.head(2)
# Out:
#                         open     high      low    close     volume
# open_time
# 2017-08-17 04:00:00  4261.48  4349.99  4261.32  4349.99  82.088865
# 2017-08-17 08:00:00  4333.32  4485.39  4333.32  4427.30  63.619882

# %%
# class to define the columns we will provide
class SignalData(PandasData):
    """
    Define pandas DataFrame structure
    """
    OHLCV = ['open', 'high', 'low', 'close', 'volume']
    cols = OHLCV

    # create lines
    lines = tuple(cols)

    # define parameters
    params = {c: -1 for c in cols}
    params.update({'datetime': None})
    params = tuple(params.items())

# %% [markdown]
# # Strategy
#
# Use two moving averages and buy in the cross of the moving average, but the RSI must be above a certain range.
#
# Then sell the position when the RSI is too high or when we achieve a certain value.

# %%
# define backtesting strategy class
class Strategy(bt.Strategy):
  params = dict()
  
  def __init__(self):

    self.btc = self.datas[0]
    self.close = self.btc.close
    self.ema_20 = btind.ExponentialMovingAverage(self.btc.close, period=20)
    self.ema_40 = btind.ExponentialMovingAverage(self.btc.close, period=40)
    # 1 if 20 crosses up 40 -1 if 20 crosses down 40
    self.cross = btind.CrossOver(self.ema_20, self.ema_40)

    self.order = None

  # logging function
  def log(self, txt):
    '''Logging function'''
    dt = self.datas[0].datetime.date(0).isoformat()
    print(f'{dt}, {txt}')

  def next(self):
    # not in the market
    if not self.position:  # not in the market
      if self.cross[0] > 0:
        self.order = self.buy()
        self.log(f'Buy at {self.btc.close[0]}')
        self.order = 'buying'

    elif self.order == 'buying': # position in market
      if self.cross[0] < 0:
        self.order = self.sell()
        self.log(f'Sell at {self.btc.close[0]}')

# %%
# instantiate SignalData class
data = SignalData(dataname=df)

# %%
# instantiate Cerebro, add strategy, data, initial cash, commission and pyfolio for performance analysis
cerebro = bt.Cerebro(stdstats = False)
cerebro.addstrategy(Strategy)
cerebro.adddata(data, name='BTC/USDT')
cerebro.broker.setcash(20000.0)
cerebro.broker.setcommission(commission=0.001)
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

# %% [markdown]
# # Analizers

# %%
# Analyzer
cerebro.addanalyzer(bt.analyzers.TradeAnalyzer, _name='ta')
cerebro.addanalyzer(bt.analyzers.DrawDown, _name='drawdown')
cerebro.addanalyzer(bt.analyzers.SharpeRatio, _name='sharpe', riskfreerate=0.0, annualize=True, timeframe=bt.TimeFrame.Minutes)
cerebro.addanalyzer(bt.analyzers.VWR, _name='vwr')
cerebro.addanalyzer(bt.analyzers.SQN, _name='sqn')
cerebro.addanalyzer(bt.analyzers.Transactions, _name='txn')

# %% [markdown]
# # Observers

# %%
cerebro.addobserver(bt.observers.TimeReturn)
cerebro.addobserver(bt.observers.BuySell)
cerebro.addobserver(bt.observers.Value)
cerebro.addobserver(bt.observers.DrawDown)
cerebro.addobserver(bt.observers.Trades)

# %%
# run the backtest
print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())
backtest_result = cerebro.run()
print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())
# Out:
# Starting Portfolio Value: 20000.00
# 2017-08-25, Buy at 4312.69
# 2017-09-04, Sell at 4153.0
# 2017-09-07, Buy at 4613.94
# 2017-09-09, Sell at 4242.01
# 2017-09-19, Buy at 3965.01
# 2017-09-21, Sell at 3605.03
# 2017-09-25, Buy at 3920.75
# 2017-10-25, Sell at 5541.51
# 2017-10-26, Buy at 5834.38
# 2017-11-10, Sell at 6506.98
# 2017-11-15, Buy at 7182.0
# 2017-12-21, Sell at 16490.99
# 2018-01-03, Buy at 14730.05
# 2018-01-09, Sell at 14400.0
# 2018-01-28, Buy at 12012.62
# 2018-01-30, Sell at 11118.99
# 2018-02-12, Buy at 8903.0
# 2018-02-23, Sell at 10033.0
# 2018-02-27, Buy at 10568.01
# 2018-03-07, Sell at 9844.18
# 2018-03-21, Buy at 8931.01
# 2018-03-25, Sell at 8470.15
# 2018-04-12, Buy at 7690.0
# 2018-05-08, Sell at 9255.01
# 2018-06-02, Buy at 7623.1
# 2018-06-05, Sell at 7428.88
# 2018-06-05, Buy at 7621.01
# 2018-06-10, Sell at 7261.03
# 2018-06-20, Buy at 6761.51
# 2018-06-22, Sell at 6348.52
# 2018-06-30, Buy at 6390.07
# 2018-07-10, Sell at 6296.91
# 2018-07-16, Buy at 6676.48
# 2018-08-01, Sell at 7539.99
# 2018-08-17, Buy at 6584.49
# 2018-08-19, Sell at 6348.95
# 2018-08-19, Buy at 6429.41
# 2018-08-19, Sell at 6375.48
# 2018-08-19, Buy at 6477.53
# 2018-08-21, Sell at 6311.96
# 2018-08-21, Buy at 6436.29
# 2018-09-06, Sell at 6444.58
# 2018-09-15, Buy at 6542.22
# 2018-09-17, Sell at 6265.06
# 2018-09-21, Buy at 6554.7
# 2018-09-25, Sell at 6363.92
# 2018-09-28, Buy at 6702.26
# 2018-10-03, Sell at 6462.09
# 2018-10-05, Buy at 6590.0
# 2018-10-11, Sell at 6340.52
# 2018-10-15, Buy at 6982.28
# 2018-10-20, Sell at 6588.4
# 2018-10-21, Buy at 6616.62
# 2018-10-22, Sell at 6563.49
# 2018-11-05, Buy at 6472.01
# 2018-11-10, Sell at 6450.08
# 2018-12-18, Buy at 3490.85
# 2018-12-27, Sell at 3711.59
# 2019-01-02, Buy at 3824.98
# 2019-01-10, Sell at 3596.12
# 2019-01-19, Buy at 3665.3
# 2019-01-20, Sell at 3524.63
# 2019-02-08, Buy at 3668.3
# 2019-02-26, Sell at 3807.63
# 2019-03-06, Buy at 3855.5
# 2019-03-25, Sell at 3922.22
# 2019-03-27, Buy at 4020.12
# 2019-04-28, Sell at 5305.91
# 2019-05-01, Buy at 5367.41
# 2019-06-04, Sell at 7895.93
# 2019-06-12, Buy at 8127.64
# 2019-07-01, Sell at 10396.98
# 2019-07-04, Buy at 11669.23
# 2019-07-05, Sell at 10970.73
# 2019-07-06, Buy at 11384.07
# 2019-07-13, Sell at 11586.71
# 2019-08-01, Buy at 9962.86
# 2019-08-13, Sell at 10951.09
# 2019-09-03, Buy at 10385.0
# 2019-09-10, Sell at 10175.07
# 2019-09-14, Buy at 10356.32
# 2019-09-16, Sell at 10117.49
# 2019-10-09, Buy at 8550.0
# 2019-10-15, Sell at 8177.59
# 2019-10-21, Buy at 8197.27
# 2019-10-23, Sell at 7957.19
# 2019-10-26, Buy at 9554.05
# 2019-11-08, Sell at 8821.14
# 2019-11-29, Buy at 7807.99
# 2019-12-01, Sell at 7358.39
# 2019-12-07, Buy at 7529.74
# 2019-12-10, Sell at 7234.13
# 2019-12-20, Buy at 7184.15
# 2019-12-31, Sell at 7173.32
# 2020-01-04, Buy at 7348.11
# 2020-01-23, Sell at 8423.0
# 2020-01-27, Buy at 8779.67
# 2020-02-16, Sell at 9745.57
# 2020-03-05, Buy at 9054.68
# 2020-03-08, Sell at 8400.83
# 2020-03-20, Buy at 6614.66
# 2020-03-29, Sell at 6138.35
# 2020-03-31, Buy at 6454.12
# 2020-04-01, Sell at 6200.81
# 2020-04-01, Buy at 6642.92
# 2020-04-11, Sell at 6803.22
# 2020-04-17, Buy at 7086.18
# 2020-04-21, Sell at 6793.29
# 2020-04-23, Buy at 7113.27
# 2020-05-11, Sell at 8696.64
# 2020-05-14, Buy at 9508.56
# 2020-05-21, Sell at 9065.53
# 2020-05-28, Buy at 9452.25
# 2020-06-11, Sell at 9280.4
# 2020-06-22, Buy at 9685.69
# 2020-06-25, Sell at 9100.36
# 2020-07-06, Buy at 9289.65
# 2020-07-15, Sell at 9219.27
# 2020-07-21, Buy at 9344.63
# 2020-08-13, Sell at 11552.11
# 2020-08-13, Buy at 11780.0
# 2020-08-21, Sell at 11715.61
# 2020-08-30, Buy at 11711.16
# 2020-09-03, Sell at 11350.56
# 2020-09-14, Buy at 10698.03
# 2020-09-21, Sell at 10417.22
# Final Portfolio Value: 34321.86

# %%
strat = backtest_result[0]
from pprint import pprint

drawdown = strat.analyzers.drawdown.get_analysis()
pprint(drawdown)
sharpe_ratio = strat.analyzers.sharpe.get_analysis()
pprint(sharpe_ratio)
transactions = strat.analyzers.txn.get_analysis()
pprint(transactions)
# Out:
# AutoOrderedDict([('len', 2723),
#                  ('drawdown', 9.921463971749978),
#                  ('moneydown', 3780.291679999973),
#                  ('max',
#                   AutoOrderedDict([('len', 3289),
#                                    ('drawdown', 16.697548446108936),
#                                    ('moneydown', 5869.90638)]))])
# OrderedDict([('sharperatio', 0.022621616375405346)])
# OrderedDict([(datetime.datetime(2017, 8, 25, 4, 0),
#               [[1, 4312.69, 0, 'BTC/USDT', -4312.69]]),
#              (datetime.datetime(2017, 9, 4, 12, 0),
#               [[-1, 4153.0, 0, 'BTC/USDT', 4153.0]]),
#              (datetime.datetime(2017, 9, 7, 12, 0),
#               [[1, 4616.79, 0, 'BTC/USDT', -4616.79]]),
#              (datetime.datetime(2017, 9, 9, 4, 0),
#               [[-1, 4254.44, 0, 'BTC/USDT', 4254.44]]),
#              (datetime.datetime(2017, 9, 19, 16, 0),
#               [[1, 3970.0, 0, 'BTC/USDT', -3970.0]]),
#              (datetime.datetime(2017, 9, 21, 20, 0),
#               [[-1, 3605.03, 0, 'BTC/USDT', 3605.03]]),
#              (datetime.datetime(2017, 9, 26, 0, 0),
#               [[1, 3928.0, 0, 'BTC/USDT', -3928.0]]),
#              (datetime.datetime(2017, 10, 25, 8, 0),
#               [[-1, 5532.02, 0, 'BTC/USDT', 5532.02]]),
#              (datetime.datetime(2017, 10, 26, 20, 0),
#               [[1, 5834.59, 0, 'BTC/USDT', -5834.59]]),
#              (datetime.datetime(2017, 11, 11, 0, 0),
#               [[-1, 6503.0, 0, 'BTC/USDT', 6503.0]]),
#              (datetime.datetime(2017, 11, 15, 20, 0),
#               [[1, 7181.98, 0, 'BTC/USDT', -7181.98]]),
#              (datetime.datetime(2017, 12, 21, 12, 0),
#               [[-1, 16491.0, 0, 'BTC/USDT', 16491.0]]),
#              (datetime.datetime(2018, 1, 3, 12, 0),
#               [[1, 14764.73, 0, 'BTC/USDT', -14764.73]]),
#              (datetime.datetime(2018, 1, 10, 0, 0),
#               [[-1, 14401.0, 0, 'BTC/USDT', 14401.0]]),
#              (datetime.datetime(2018, 1, 28, 12, 0),
#               [[1, 12001.94, 0, 'BTC/USDT', -12001.94]]),
#              (datetime.datetime(2018, 1, 30, 8, 0),
#               [[-1, 11119.0, 0, 'BTC/USDT', 11119.0]]),
#              (datetime.datetime(2018, 2, 13, 0, 0),
#               [[1, 8903.0, 0, 'BTC/USDT', -8903.0]]),
#              (datetime.datetime(2018, 2, 23, 20, 0),
#               [[-1, 10037.9, 0, 'BTC/USDT', 10037.9]]),
#              (datetime.datetime(2018, 2, 27, 16, 0),
#               [[1, 10570.0, 0, 'BTC/USDT', -10570.0]]),
#              (datetime.datetime(2018, 3, 7, 20, 0),
#               [[-1, 9837.84, 0, 'BTC/USDT', 9837.84]]),
#              (datetime.datetime(2018, 3, 21, 8, 0),
#               [[1, 8931.0, 0, 'BTC/USDT', -8931.0]]),
#              (datetime.datetime(2018, 3, 26, 0, 0),
#               [[-1, 8470.14, 0, 'BTC/USDT', 8470.14]]),
#              (datetime.datetime(2018, 4, 12, 12, 0),
#               [[1, 7685.55, 0, 'BTC/USDT', -7685.55]]),
#              (datetime.datetime(2018, 5, 8, 20, 0),
#               [[-1, 9255.0, 0, 'BTC/USDT', 9255.0]]),
#              (datetime.datetime(2018, 6, 2, 16, 0),
#               [[1, 7623.09, 0, 'BTC/USDT', -7623.09]]),
#              (datetime.datetime(2018, 6, 5, 12, 0),
#               [[-1, 7422.1, 0, 'BTC/USDT', 7422.1]]),
#              (datetime.datetime(2018, 6, 5, 20, 0),
#               [[1, 7620.01, 0, 'BTC/USDT', -7620.01]]),
#              (datetime.datetime(2018, 6, 10, 4, 0),
#               [[-1, 7261.03, 0, 'BTC/USDT', 7261.03]]),
#              (datetime.datetime(2018, 6, 21, 0, 0),
#               [[1, 6763.21, 0, 'BTC/USDT', -6763.21]]),
#              (datetime.datetime(2018, 6, 22, 12, 0),
#               [[-1, 6351.0, 0, 'BTC/USDT', 6351.0]]),
#              (datetime.datetime(2018, 7, 1, 0, 0),
#               [[1, 6391.08, 0, 'BTC/USDT', -6391.08]]),
#              (datetime.datetime(2018, 7, 11, 0, 0),
#               [[-1, 6296.91, 0, 'BTC/USDT', 6296.91]]),
#              (datetime.datetime(2018, 7, 16, 20, 0),
#               [[1, 6681.95, 0, 'BTC/USDT', -6681.95]]),
#              (datetime.datetime(2018, 8, 1, 4, 0),
#               [[-1, 7540.0, 0, 'BTC/USDT', 7540.0]]),
#              (datetime.datetime(2018, 8, 18, 0, 0),
#               [[1, 6579.04, 0, 'BTC/USDT', -6579.04]]),
#              (datetime.datetime(2018, 8, 19, 8, 0),
#               [[-1, 6347.62, 0, 'BTC/USDT', 6347.62]]),
#              (datetime.datetime(2018, 8, 19, 12, 0),
#               [[1, 6429.41, 0, 'BTC/USDT', -6429.41]]),
#              (datetime.datetime(2018, 8, 19, 20, 0),
#               [[-1, 6375.46, 0, 'BTC/USDT', 6375.46]]),
#              (datetime.datetime(2018, 8, 20, 0, 0),
#               [[1, 6477.53, 0, 'BTC/USDT', -6477.53]]),
#              (datetime.datetime(2018, 8, 21, 4, 0),
#               [[-1, 6311.96, 0, 'BTC/USDT', 6311.96]]),
#              (datetime.datetime(2018, 8, 21, 20, 0),
#               [[1, 6437.99, 0, 'BTC/USDT', -6437.99]]),
#              (datetime.datetime(2018, 9, 6, 4, 0),
#               [[-1, 6444.6, 0, 'BTC/USDT', 6444.6]]),
#              (datetime.datetime(2018, 9, 15, 16, 0),
#               [[1, 6542.18, 0, 'BTC/USDT', -6542.18]]),
#              (datetime.datetime(2018, 9, 17, 16, 0),
#               [[-1, 6262.1, 0, 'BTC/USDT', 6262.1]]),
#              (datetime.datetime(2018, 9, 21, 4, 0),
#               [[1, 6554.67, 0, 'BTC/USDT', -6554.67]]),
#              (datetime.datetime(2018, 9, 25, 20, 0),
#               [[-1, 6362.91, 0, 'BTC/USDT', 6362.91]]),
#              (datetime.datetime(2018, 9, 28, 4, 0),
#               [[1, 6702.26, 0, 'BTC/USDT', -6702.26]]),
#              (datetime.datetime(2018, 10, 3, 4, 0),
#               [[-1, 6464.0, 0, 'BTC/USDT', 6464.0]]),
#              (datetime.datetime(2018, 10, 5, 12, 0),
#               [[1, 6589.6, 0, 'BTC/USDT', -6589.6]]),
#              (datetime.datetime(2018, 10, 11, 4, 0),
#               [[-1, 6340.52, 0, 'BTC/USDT', 6340.52]]),
#              (datetime.datetime(2018, 10, 15, 12, 0),
#               [[1, 6982.28, 0, 'BTC/USDT', -6982.28]]),
#              (datetime.datetime(2018, 10, 21, 0, 0),
#               [[-1, 6585.72, 0, 'BTC/USDT', 6585.72]]),
#              (datetime.datetime(2018, 10, 21, 4, 0),
#               [[1, 6616.63, 0, 'BTC/USDT', -6616.63]]),
#              (datetime.datetime(2018, 10, 22, 16, 0),
#               [[-1, 6562.71, 0, 'BTC/USDT', 6562.71]]),
#              (datetime.datetime(2018, 11, 5, 8, 0),
#               [[1, 6472.64, 0, 'BTC/USDT', -6472.64]]),
#              (datetime.datetime(2018, 11, 10, 12, 0),
#               [[-1, 6450.08, 0, 'BTC/USDT', 6450.08]]),
#              (datetime.datetime(2018, 12, 18, 12, 0),
#               [[1, 3490.85, 0, 'BTC/USDT', -3490.85]]),
#              (datetime.datetime(2018, 12, 27, 4, 0),
#               [[-1, 3709.47, 0, 'BTC/USDT', 3709.47]]),
#              (datetime.datetime(2019, 1, 2, 20, 0),
#               [[1, 3824.98, 0, 'BTC/USDT', -3824.98]]),
#              (datetime.datetime(2019, 1, 10, 20, 0),
#               [[-1, 3596.73, 0, 'BTC/USDT', 3596.73]]),
#              (datetime.datetime(2019, 1, 20, 0, 0),
#               [[1, 3665.75, 0, 'BTC/USDT', -3665.75]]),
#              (datetime.datetime(2019, 1, 20, 16, 0),
#               [[-1, 3524.57, 0, 'BTC/USDT', 3524.57]]),
#              (datetime.datetime(2019, 2, 8, 20, 0),
#               [[1, 3668.28, 0, 'BTC/USDT', -3668.28]]),
#              (datetime.datetime(2019, 2, 26, 8, 0),
#               [[-1, 3807.63, 0, 'BTC/USDT', 3807.63]]),
#              (datetime.datetime(2019, 3, 6, 20, 0),
#               [[1, 3855.5, 0, 'BTC/USDT', -3855.5]]),
#              (datetime.datetime(2019, 3, 25, 20, 0),
#               [[-1, 3922.22, 0, 'BTC/USDT', 3922.22]]),
#              (datetime.datetime(2019, 3, 27, 20, 0),
#               [[1, 4019.99, 0, 'BTC/USDT', -4019.99]]),
#              (datetime.datetime(2019, 4, 28, 4, 0),
#               [[-1, 5306.57, 0, 'BTC/USDT', 5306.57]]),
#              (datetime.datetime(2019, 5, 1, 20, 0),
#               [[1, 5365.98, 0, 'BTC/USDT', -5365.98]]),
#              (datetime.datetime(2019, 6, 4, 4, 0),
#               [[-1, 7895.91, 0, 'BTC/USDT', 7895.91]]),
#              (datetime.datetime(2019, 6, 13, 0, 0),
#               [[1, 8127.64, 0, 'BTC/USDT', -8127.64]]),
#              (datetime.datetime(2019, 7, 1, 16, 0),
#               [[-1, 10390.17, 0, 'BTC/USDT', 10390.17]]),
#              (datetime.datetime(2019, 7, 4, 8, 0),
#               [[1, 11669.23, 0, 'BTC/USDT', -11669.23]]),
#              (datetime.datetime(2019, 7, 6, 0, 0),
#               [[-1, 10982.41, 0, 'BTC/USDT', 10982.41]]),
#              (datetime.datetime(2019, 7, 6, 8, 0),
#               [[1, 11384.13, 0, 'BTC/USDT', -11384.13]]),
#              (datetime.datetime(2019, 7, 13, 4, 0),
#               [[-1, 11582.06, 0, 'BTC/USDT', 11582.06]]),
#              (datetime.datetime(2019, 8, 1, 12, 0),
#               [[1, 9962.86, 0, 'BTC/USDT', -9962.86]]),
#              (datetime.datetime(2019, 8, 13, 16, 0),
#               [[-1, 10952.74, 0, 'BTC/USDT', 10952.74]]),
#              (datetime.datetime(2019, 9, 3, 4, 0),
#               [[1, 10385.33, 0, 'BTC/USDT', -10385.33]]),
#              (datetime.datetime(2019, 9, 10, 16, 0),
#               [[-1, 10176.26, 0, 'BTC/USDT', 10176.26]]),
#              (datetime.datetime(2019, 9, 14, 16, 0),
#               [[1, 10357.78, 0, 'BTC/USDT', -10357.78]]),
#              (datetime.datetime(2019, 9, 16, 16, 0),
#               [[-1, 10119.73, 0, 'BTC/USDT', 10119.73]]),
#              (datetime.datetime(2019, 10, 9, 16, 0),
#               [[1, 8552.46, 0, 'BTC/USDT', -8552.46]]),
#              (datetime.datetime(2019, 10, 15, 20, 0),
#               [[-1, 8177.1, 0, 'BTC/USDT', 8177.1]]),
#              (datetime.datetime(2019, 10, 22, 0, 0),
#               [[1, 8197.28, 0, 'BTC/USDT', -8197.28]]),
#              (datetime.datetime(2019, 10, 23, 8, 0),
#               [[-1, 7957.34, 0, 'BTC/USDT', 7957.34]]),
#              (datetime.datetime(2019, 10, 26, 4, 0),
#               [[1, 9554.05, 0, 'BTC/USDT', -9554.05]]),
#              (datetime.datetime(2019, 11, 8, 16, 0),
#               [[-1, 8820.76, 0, 'BTC/USDT', 8820.76]]),
#              (datetime.datetime(2019, 11, 29, 16, 0),
#               [[1, 7808.06, 0, 'BTC/USDT', -7808.06]]),
#              (datetime.datetime(2019, 12, 1, 20, 0),
#               [[-1, 7355.83, 0, 'BTC/USDT', 7355.83]]),
#              (datetime.datetime(2019, 12, 7, 4, 0),
#               [[1, 7528.62, 0, 'BTC/USDT', -7528.62]]),
#              (datetime.datetime(2019, 12, 10, 16, 0),
#               [[-1, 7236.4, 0, 'BTC/USDT', 7236.4]]),
#              (datetime.datetime(2019, 12, 20, 20, 0),
#               [[1, 7183.99, 0, 'BTC/USDT', -7183.99]]),
#              (datetime.datetime(2019, 12, 31, 20, 0),
#               [[-1, 7173.75, 0, 'BTC/USDT', 7173.75]]),
#              (datetime.datetime(2020, 1, 4, 8, 0),
#               [[1, 7348.04, 0, 'BTC/USDT', -7348.04]]),
#              (datetime.datetime(2020, 1, 23, 12, 0),
#               [[-1, 8422.98, 0, 'BTC/USDT', 8422.98]]),
#              (datetime.datetime(2020, 1, 27, 16, 0),
#               [[1, 8779.68, 0, 'BTC/USDT', -8779.68]]),
#              (datetime.datetime(2020, 2, 16, 20, 0),
#               [[-1, 9745.91, 0, 'BTC/USDT', 9745.91]]),
#              (datetime.datetime(2020, 3, 6, 0, 0),
#               [[1, 9054.64, 0, 'BTC/USDT', -9054.64]]),
#              (datetime.datetime(2020, 3, 8, 16, 0),
#               [[-1, 8400.85, 0, 'BTC/USDT', 8400.85]]),
#              (datetime.datetime(2020, 3, 20, 16, 0),
#               [[1, 6614.32, 0, 'BTC/USDT', -6614.32]]),
#              (datetime.datetime(2020, 3, 29, 12, 0),
#               [[-1, 6138.36, 0, 'BTC/USDT', 6138.36]]),
#              (datetime.datetime(2020, 3, 31, 16, 0),
#               [[1, 6454.12, 0, 'BTC/USDT', -6454.12]]),
#              (datetime.datetime(2020, 4, 1, 20, 0),
#               [[-1, 6200.11, 0, 'BTC/USDT', 6200.11]]),
#              (datetime.datetime(2020, 4, 2, 0, 0),
#               [[1, 6643.36, 0, 'BTC/USDT', -6643.36]]),
#              (datetime.datetime(2020, 4, 11, 20, 0),
#               [[-1, 6803.22, 0, 'BTC/USDT', 6803.22]]),
#              (datetime.datetime(2020, 4, 17, 4, 0),
#               [[1, 7086.18, 0, 'BTC/USDT', -7086.18]]),
#              (datetime.datetime(2020, 4, 21, 12, 0),
#               [[-1, 6792.79, 0, 'BTC/USDT', 6792.79]]),
#              (datetime.datetime(2020, 4, 23, 4, 0),
#               [[1, 7113.27, 0, 'BTC/USDT', -7113.27]]),
#              (datetime.datetime(2020, 5, 11, 4, 0),
#               [[-1, 8696.24, 0, 'BTC/USDT', 8696.24]]),
#              (datetime.datetime(2020, 5, 14, 8, 0),
#               [[1, 9508.56, 0, 'BTC/USDT', -9508.56]]),
#              (datetime.datetime(2020, 5, 21, 20, 0),
#               [[-1, 9065.81, 0, 'BTC/USDT', 9065.81]]),
#              (datetime.datetime(2020, 5, 28, 20, 0),
#               [[1, 9452.24, 0, 'BTC/USDT', -9452.24]]),
#              (datetime.datetime(2020, 6, 12, 0, 0),
#               [[-1, 9278.88, 0, 'BTC/USDT', 9278.88]]),
#              (datetime.datetime(2020, 6, 23, 0, 0),
#               [[1, 9685.69, 0, 'BTC/USDT', -9685.69]]),
#              (datetime.datetime(2020, 6, 25, 4, 0),
#               [[-1, 9100.13, 0, 'BTC/USDT', 9100.13]]),
#              (datetime.datetime(2020, 7, 6, 20, 0),
#               [[1, 9289.62, 0, 'BTC/USDT', -9289.62]]),
#              (datetime.datetime(2020, 7, 15, 12, 0),
#               [[-1, 9219.22, 0, 'BTC/USDT', 9219.22]]),
#              (datetime.datetime(2020, 7, 21, 12, 0),
#               [[1, 9344.64, 0, 'BTC/USDT', -9344.64]]),
#              (datetime.datetime(2020, 8, 13, 12, 0),
#               [[-1, 11552.12, 0, 'BTC/USDT', 11552.12]]),
#              (datetime.datetime(2020, 8, 14, 0, 0),
#               [[1, 11779.77, 0, 'BTC/USDT', -11779.77]]),
#              (datetime.datetime(2020, 8, 21, 12, 0),
#               [[-1, 11715.6, 0, 'BTC/USDT', 11715.6]]),
#              (datetime.datetime(2020, 8, 31, 0, 0),
#               [[1, 11711.17, 0, 'BTC/USDT', -11711.17]]),
#              (datetime.datetime(2020, 9, 3, 4, 0),
#               [[-1, 11350.57, 0, 'BTC/USDT', 11350.57]]),
#              (datetime.datetime(2020, 9, 14, 16, 0),
#               [[1, 10698.03, 0, 'BTC/USDT', -10698.03]]),
#              (datetime.datetime(2020, 9, 22, 0, 0),
#               [[-1, 10417.22, 0, 'BTC/USDT', 10417.22]])])

# %%
cerebro.plot()
# Out:
# <div id='fc9e901d-c34f-4d6f-8053-f0a03f4c50dc'></div>
# [[<Figure size 432x288 with 7 Axes>]]
